# %% [markdown]
# ##Name : Mohd Wasiuddin Junaid
# ##email : mdwasi03@gmail.com
# ##phone : 6302230780
# ##Github: https://github.com/mohdwasi03/docker-project

# %%
# !pip install psycopg2-binary
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 50.3 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import psycopg2 as ps
import pandas.io.sql as sqlio

# %%
connection = ps.connect(dbname = "data",
                        user = "wasi",      
                        password = "12345",
                        host = "postgres-container",
                        port = "5432")

# %%
df = sqlio.read_sql_query("""select * from info""", connection)
df[:105]
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#      customer_id  gender  age  annual_income  spending_score
# 0              1    Male   19             15              39
# 1              2    Male   21             15              81
# 2              3  Female   20             16               6
# 3              4  Female   23             16              77
# 4              5  Female   31             17              40
# ..           ...     ...  ...            ...             ...
# 100          101  Female   23             62              41
# 101          102  Female   49             62              48
# 102          103    Male   67             62              59
# 103          104    Male   26             62              55
# ...

# %%
df = sqlio.read_sql_query(""" select gender,count(*) from info group by gender  """, connection)
df
# Out:
#    gender  count
# 0  Female    112
# 1    Male     87

# %%
df = sqlio.read_sql_query(""" select customer_id,spending_score from info where spending_score > 75 order by spending_score desc """, connection)
df
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#     customer_id  spending_score
# 0            12              99
# 1            20              98
# 2           146              97
# 3           186              97
# 4           128              95
# 5           168              95
# 6             8              94
# 7           164              93
# 8           142              93
# 9           174              92
# 10           34              92
# 11           42              92
# 12          194              91
# 13          124              91
# 14          150              90
# 15          180              90
# 16          156              89
# 17          136              88
# 18          152              88
# 19          184              88
# ...

# %%
df = sqlio.read_sql_query(""" select age,count(*),avg(annual_income) as average_annual_income,avg(spending_score) as average_spending_score from info group by  age order by average_spending_score desc """, connection)
df
# Out:
# /opt/conda/lib/python3.9/site-packages/pandas/io/sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#     age  count  average_annual_income  average_spending_score
# 0    39      3              72.666667               84.666667
# 1    30      6              66.000000               79.833333
# 2    29      5              63.600000               76.600000
# 3    24      4              39.250000               71.500000
# 4    22      3              31.333333               70.000000
# 5    28      4              85.250000               70.000000
# 6    21      5              38.800000               66.800000
# 7    32     11              87.181818               66.000000
# 8    35      9              46.666667               63.888889
# 9    31      8              48.375000               63.875000
# ...
